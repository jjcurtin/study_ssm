# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
def gen_trajectory(a,c,horizon):
    x=np.empty(90)

# %%
# Testing
horizon = 90
x=np.empty(horizon)
T = range(horizon)
x0_set = np.linspace(0.1,0.9,9)
trajs = {}
a=.9
c=.02
data_list=[]
for x0 in x0_set:
    for t in T:
        if t==0:
            current_x=x0
        else:
            current_x=a*last_x+c
        last_x=current_x
        temp_df = pd.DataFrame({'a':a,'c':c,'x0':x0,'t':t,'x':current_x},index=[0])
        data_list.append(temp_df)
data = pd.concat(data_list,ignore_index=True)
data.head()
fig,ax = plt.subplots(figsize=(10,6))
sns.lineplot(ax=ax,data=data,x='t',y='x',estimator=None,units='x0',hue='x0',hue_order=x0_set)
